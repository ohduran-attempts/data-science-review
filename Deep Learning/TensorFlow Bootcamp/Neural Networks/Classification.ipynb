# %% [markdown]
# # Classification in TensorFlow

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x-x.min())/(x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
import tensorflow as tf
# Out:
# /home/alvaro/anaconda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group', ['A', 'B', 'C', 'D'])

# %%
# But if you don't know the categories...
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20);

# %%
#let's group them by decade
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80,90])

# %%
feat_cols =[num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, assigned_group, age_bucket]

# %% [markdown]
# ## Train the model

# %%
x_data = diabetes.drop('Class', axis=1)
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_data, labels, test_size=0.3, random_state=101)

# %%
# Labels

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpc4fh113h
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpc4fh113h', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f194f4d2da0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpc4fh113h/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 163.878
# INFO:tensorflow:loss = 4.145743, step = 101 (0.619 sec)
# INFO:tensorflow:global_step/sec: 298.481
# INFO:tensorflow:loss = 6.445324, step = 201 (0.331 sec)
# INFO:tensorflow:global_step/sec: 264.837
# INFO:tensorflow:loss = 6.7913084, step = 301 (0.389 sec)
# INFO:tensorflow:global_step/sec: 229.303
# INFO:tensorflow:loss = 4.8834896, step = 401 (0.430 sec)
# INFO:tensorflow:global_step/sec: 222.569
# INFO:tensorflow:loss = 4.0396123, step = 501 (0.444 sec)
# INFO:tensorflow:global_step/sec: 230.612
# INFO:tensorflow:loss = 4.7330847, step = 601 (0.434 sec)
# INFO:tensorflow:global_step/sec: 218.258
# INFO:tensorflow:loss = 4.335657, step = 701 (0.458 sec)
# INFO:tensorflow:global_step/sec: 224.239
# INFO:tensorflow:loss = 5.348684, step = 801 (0.445 sec)
# INFO:tensorflow:global_step/sec: 226.089
# INFO:tensorflow:loss = 5.6391797, step = 901 (0.444 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpc4fh113h/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.4844465.

# %%
eval_input_func=tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-31-09:10:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc4fh113h/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-31-09:10:10
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.74458873, accuracy_baseline = 0.64935064, auc = 0.8030453, auc_precision_recall = 0.6516799, average_loss = 0.5245612, global_step = 1000, label/mean = 0.35064936, loss = 5.048902, precision = 0.6666667, prediction/mean = 0.35835955, recall = 0.54320985

# %%
results
# Out:
# {'accuracy': 0.74458873,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8030453,
#  'auc_precision_recall': 0.6516799,
#  'average_loss': 0.5245612,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 5.048902,
#  'precision': 0.6666667,
#  'prediction/mean': 0.35835955,
#  'recall': 0.54320985}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc4fh113h/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
my_pred
# Out:
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5141054], dtype=float32),
#   'logits': array([0.05643642], dtype=float32),
#   'probabilities': array([0.48589468, 0.5141054 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6281857], dtype=float32),
#   'logits': array([0.5244411], dtype=float32),
#   'probabilities': array([0.37181434, 0.6281857 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36417082], dtype=float32),
#   'logits': array([-0.5573068], dtype=float32),
#   'probabilities': array([0.63582915, 0.36417082], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3242561], dtype=float32),
#   'logits': array([-0.7342806], dtype=float32),
#   'probabilities': array([0.67574394, 0.3242561 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14190073], dtype=float32),
#   'logits': array([-1.799592], dtype=float32),
#   'probabilities': array([0.8580993 , 0.14190073], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6684246], dtype=float32),
#   'logits': array([0.7010685], dtype=float32),
#   'probabilities': array([0.33157536, 0.6684246 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59911287], dtype=float32),
#   'logits': array([0.40177023], dtype=float32),
#   'probabilities': array([0.4008871 , 0.59911287], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32297465], dtype=float32),
#   'logits': array([-0.74013495], dtype=float32),
#   'probabilities': array([0.6770253 , 0.32297462], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23028213], dtype=float32),
#   'logits': array([-1.2067188], dtype=float32),
#   'probabilities': array([0.7697179 , 0.23028213], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23177406], dtype=float32),
#   'logits': array([-1.1983207], dtype=float32),
#   'probabilities': array([0.76822597, 0.23177409], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13545461], dtype=float32),
#   'logits': array([-1.8535671], dtype=float32),
#   'probabilities': array([0.8645454 , 0.13545462], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15348206], dtype=float32),
#   'logits': array([-1.7075477], dtype=float32),
#   'probabilities': array([0.8465179 , 0.15348206], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28661102], dtype=float32),
#   'logits': array([-0.9119008], dtype=float32),
#   'probabilities': array([0.713389  , 0.28661105], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5510444], dtype=float32),
#   'logits': array([0.20489144], dtype=float32),
#   'probabilities': array([0.4489556, 0.5510444], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17840646], dtype=float32),
#   'logits': array([-1.5271814], dtype=float32),
#   'probabilities': array([0.8215935 , 0.17840645], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3257977], dtype=float32),
#   'logits': array([-0.7272536], dtype=float32),
#   'probabilities': array([0.6742023, 0.3257977], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36271372], dtype=float32),
#   'logits': array([-0.56360507], dtype=float32),
#   'probabilities': array([0.63728625, 0.36271372], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13082631], dtype=float32),
#   'logits': array([-1.8936725], dtype=float32),
#   'probabilities': array([0.86917365, 0.1308263 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35295522], dtype=float32),
#   'logits': array([-0.6060742], dtype=float32),
#   'probabilities': array([0.6470448 , 0.35295525], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14161177], dtype=float32),
#   'logits': array([-1.8019671], dtype=float32),
#   'probabilities': array([0.85838825, 0.14161177], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21055792], dtype=float32),
#   'logits': array([-1.3215657], dtype=float32),
#   'probabilities': array([0.78944206, 0.21055791], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28273982], dtype=float32),
#   'logits': array([-0.93091154], dtype=float32),
#   'probabilities': array([0.7172602 , 0.28273982], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6324869], dtype=float32),
#   'logits': array([0.5429007], dtype=float32),
#   'probabilities': array([0.36751306, 0.6324869 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2081688], dtype=float32),
#   'logits': array([-1.335999], dtype=float32),
#   'probabilities': array([0.79183125, 0.2081688 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17576332], dtype=float32),
#   'logits': array([-1.5453193], dtype=float32),
#   'probabilities': array([0.8242367 , 0.17576334], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7615786], dtype=float32),
#   'logits': array([1.1613537], dtype=float32),
#   'probabilities': array([0.23842141, 0.7615786 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17335878], dtype=float32),
#   'logits': array([-1.5620074], dtype=float32),
#   'probabilities': array([0.8266412 , 0.17335878], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3100124], dtype=float32),
#   'logits': array([-0.80006135], dtype=float32),
#   'probabilities': array([0.6899876, 0.3100124], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10815211], dtype=float32),
#   'logits': array([-2.109757], dtype=float32),
#   'probabilities': array([0.8918479 , 0.10815211], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5626618], dtype=float32),
#   'logits': array([0.25197196], dtype=float32),
#   'probabilities': array([0.43733823, 0.5626618 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9348284], dtype=float32),
#   'logits': array([2.6633396], dtype=float32),
#   'probabilities': array([0.06517157, 0.9348284 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4006327], dtype=float32),
#   'logits': array([-0.40282947], dtype=float32),
#   'probabilities': array([0.5993673 , 0.40063277], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31495932], dtype=float32),
#   'logits': array([-0.7770348], dtype=float32),
#   'probabilities': array([0.68504065, 0.3149593 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53323036], dtype=float32),
#   'logits': array([0.13311768], dtype=float32),
#   'probabilities': array([0.46676964, 0.53323036], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23856278], dtype=float32),
#   'logits': array([-1.1605753], dtype=float32),
#   'probabilities': array([0.76143724, 0.23856276], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36806527], dtype=float32),
#   'logits': array([-0.5405258], dtype=float32),
#   'probabilities': array([0.6319347 , 0.36806527], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48691213], dtype=float32),
#   'logits': array([-0.05236328], dtype=float32),
#   'probabilities': array([0.5130878 , 0.48691216], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6070987], dtype=float32),
#   'logits': array([0.43513286], dtype=float32),
#   'probabilities': array([0.3929013, 0.6070987], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74968517], dtype=float32),
#   'logits': array([1.0969337], dtype=float32),
#   'probabilities': array([0.2503149 , 0.74968517], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32865182], dtype=float32),
#   'logits': array([-0.71428907], dtype=float32),
#   'probabilities': array([0.6713482 , 0.32865182], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17534974], dtype=float32),
#   'logits': array([-1.5481769], dtype=float32),
#   'probabilities': array([0.8246503 , 0.17534974], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54545856], dtype=float32),
#   'logits': array([0.18233764], dtype=float32),
#   'probabilities': array([0.45454147, 0.54545856], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15234964], dtype=float32),
#   'logits': array([-1.7162901], dtype=float32),
#   'probabilities': array([0.84765035, 0.15234964], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5177338], dtype=float32),
#   'logits': array([0.07096505], dtype=float32),
#   'probabilities': array([0.4822662, 0.5177338], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1394475], dtype=float32),
#   'logits': array([-1.8198864], dtype=float32),
#   'probabilities': array([0.8605525, 0.1394475], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11930384], dtype=float32),
#   'logits': array([-1.9990392], dtype=float32),
#   'probabilities': array([0.8806962 , 0.11930384], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5804473], dtype=float32),
#   'logits': array([0.32461], dtype=float32),
#   'probabilities': array([0.41955265, 0.5804473 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17715333], dtype=float32),
#   'logits': array([-1.5357542], dtype=float32),
#   'probabilities': array([0.82284665, 0.17715333], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19341555], dtype=float32),
#   'logits': array([-1.4279677], dtype=float32),
#   'probabilities': array([0.8065844 , 0.19341554], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13440222], dtype=float32),
#   'logits': array([-1.8625834], dtype=float32),
#   'probabilities': array([0.86559784, 0.13440223], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17196056], dtype=float32),
#   'logits': array([-1.5717956], dtype=float32),
#   'probabilities': array([0.8280394 , 0.17196056], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24185006], dtype=float32),
#   'logits': array([-1.1425632], dtype=float32),
#   'probabilities': array([0.75815   , 0.24185008], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25352547], dtype=float32),
#   'logits': array([-1.0798973], dtype=float32),
#   'probabilities': array([0.74647456, 0.25352547], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35916388], dtype=float32),
#   'logits': array([-0.578995], dtype=float32),
#   'probabilities': array([0.6408362, 0.3591639], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.126159], dtype=float32),
#   'logits': array([-1.9353555], dtype=float32),
#   'probabilities': array([0.873841  , 0.12615898], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22201839], dtype=float32),
#   'logits': array([-1.2539427], dtype=float32),
#   'probabilities': array([0.77798164, 0.22201839], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20303102], dtype=float32),
#   'logits': array([-1.367457], dtype=float32),
#   'probabilities': array([0.796969  , 0.20303102], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20977668], dtype=float32),
#   'logits': array([-1.326272], dtype=float32),
#   'probabilities': array([0.79022336, 0.20977671], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46565923], dtype=float32),
#   'logits': array([-0.13757968], dtype=float32),
#   'probabilities': array([0.53434074, 0.4656592 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16057706], dtype=float32),
#   'logits': array([-1.6539407], dtype=float32),
#   'probabilities': array([0.83942294, 0.16057707], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22556941], dtype=float32),
#   'logits': array([-1.2335001], dtype=float32),
#   'probabilities': array([0.7744306, 0.2255694], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6153452], dtype=float32),
#   'logits': array([0.46983707], dtype=float32),
#   'probabilities': array([0.38465482, 0.6153452 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.614663], dtype=float32),
#   'logits': array([0.4669559], dtype=float32),
#   'probabilities': array([0.38533697, 0.614663  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50020885], dtype=float32),
#   'logits': array([0.00083554], dtype=float32),
#   'probabilities': array([0.4997911 , 0.50020885], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3544031], dtype=float32),
#   'logits': array([-0.5997404], dtype=float32),
#   'probabilities': array([0.6455969, 0.3544031], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46847436], dtype=float32),
#   'logits': array([-0.12627], dtype=float32),
#   'probabilities': array([0.5315256, 0.4684744], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18490858], dtype=float32),
#   'logits': array([-1.4834387], dtype=float32),
#   'probabilities': array([0.81509143, 0.18490858], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19170299], dtype=float32),
#   'logits': array([-1.4389822], dtype=float32),
#   'probabilities': array([0.808297  , 0.19170299], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14770363], dtype=float32),
#   'logits': array([-1.7527266], dtype=float32),
#   'probabilities': array([0.8522964 , 0.14770363], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1257303], dtype=float32),
#   'logits': array([-1.9392498], dtype=float32),
#   'probabilities': array([0.87426966, 0.1257303 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6082565], dtype=float32),
#   'logits': array([0.43998957], dtype=float32),
#   'probabilities': array([0.39174345, 0.6082565 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22847627], dtype=float32),
#   'logits': array([-1.216935], dtype=float32),
#   'probabilities': array([0.7715238, 0.2284763], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4242742], dtype=float32),
#   'logits': array([-0.30525148], dtype=float32),
#   'probabilities': array([0.5757258, 0.4242742], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56486654], dtype=float32),
#   'logits': array([0.26093662], dtype=float32),
#   'probabilities': array([0.4351335 , 0.56486654], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2941659], dtype=float32),
#   'logits': array([-0.8752363], dtype=float32),
#   'probabilities': array([0.7058341, 0.2941659], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61368674], dtype=float32),
#   'logits': array([0.4628359], dtype=float32),
#   'probabilities': array([0.3863133 , 0.61368674], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12639385], dtype=float32),
#   'logits': array([-1.9332268], dtype=float32),
#   'probabilities': array([0.87360615, 0.12639385], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60783464], dtype=float32),
#   'logits': array([0.4382193], dtype=float32),
#   'probabilities': array([0.39216536, 0.60783464], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12779315], dtype=float32),
#   'logits': array([-1.9206136], dtype=float32),
#   'probabilities': array([0.87220687, 0.12779315], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5495378], dtype=float32),
#   'logits': array([0.19880319], dtype=float32),
#   'probabilities': array([0.45046228, 0.5495378 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3257644], dtype=float32),
#   'logits': array([-0.7274053], dtype=float32),
#   'probabilities': array([0.67423564, 0.3257644 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1621798], dtype=float32),
#   'logits': array([-1.642098], dtype=float32),
#   'probabilities': array([0.83782023, 0.1621798 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5443123], dtype=float32),
#   'logits': array([0.17771554], dtype=float32),
#   'probabilities': array([0.45568767, 0.5443123 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58446765], dtype=float32),
#   'logits': array([0.34114087], dtype=float32),
#   'probabilities': array([0.41553238, 0.58446765], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5393076], dtype=float32),
#   'logits': array([0.15755558], dtype=float32),
#   'probabilities': array([0.46069238, 0.5393076 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16421002], dtype=float32),
#   'logits': array([-1.6272311], dtype=float32),
#   'probabilities': array([0.8357899, 0.16421  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36565274], dtype=float32),
#   'logits': array([-0.55091244], dtype=float32),
#   'probabilities': array([0.63434726, 0.36565277], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15205936], dtype=float32),
#   'logits': array([-1.7185397], dtype=float32),
#   'probabilities': array([0.8479406 , 0.15205935], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6866128], dtype=float32),
#   'logits': array([0.7843311], dtype=float32),
#   'probabilities': array([0.3133872, 0.6866128], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.79285663], dtype=float32),
#   'logits': array([1.3422312], dtype=float32),
#   'probabilities': array([0.20714338, 0.79285663], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60516584], dtype=float32),
#   'logits': array([0.42703664], dtype=float32),
#   'probabilities': array([0.3948342 , 0.60516584], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20803106], dtype=float32),
#   'logits': array([-1.3368347], dtype=float32),
#   'probabilities': array([0.79196894, 0.20803109], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46152204], dtype=float32),
#   'logits': array([-0.15421665], dtype=float32),
#   'probabilities': array([0.53847796, 0.46152207], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3740745], dtype=float32),
#   'logits': array([-0.5147764], dtype=float32),
#   'probabilities': array([0.6259255 , 0.37407446], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43455365], dtype=float32),
#   'logits': array([-0.263296], dtype=float32),
#   'probabilities': array([0.5654463 , 0.43455362], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3535696], dtype=float32),
#   'logits': array([-0.60338515], dtype=float32),
#   'probabilities': array([0.6464304, 0.3535696], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42476207], dtype=float32),
#   'logits': array([-0.3032546], dtype=float32),
#   'probabilities': array([0.57523793, 0.42476204], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15327032], dtype=float32),
#   'logits': array([-1.7091784], dtype=float32),
#   'probabilities': array([0.8467297, 0.1532703], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54849255], dtype=float32),
#   'logits': array([0.19458187], dtype=float32),
#   'probabilities': array([0.45150742, 0.54849255], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5324385], dtype=float32),
#   'logits': array([0.12993658], dtype=float32),
#   'probabilities': array([0.46756148, 0.5324385 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23835373], dtype=float32),
#   'logits': array([-1.1617264], dtype=float32),
#   'probabilities': array([0.7616463 , 0.23835374], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.175635], dtype=float32),
#   'logits': array([-1.5462054], dtype=float32),
#   'probabilities': array([0.824365  , 0.17563501], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16672319], dtype=float32),
#   'logits': array([-1.609031], dtype=float32),
#   'probabilities': array([0.83327687, 0.1667232 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26949486], dtype=float32),
#   'logits': array([-0.99718696], dtype=float32),
#   'probabilities': array([0.7305051 , 0.26949486], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37058356], dtype=float32),
#   'logits': array([-0.5297142], dtype=float32),
#   'probabilities': array([0.62941647, 0.37058353], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13523102], dtype=float32),
#   'logits': array([-1.8554778], dtype=float32),
#   'probabilities': array([0.8647689 , 0.13523102], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32139033], dtype=float32),
#   'logits': array([-0.7473898], dtype=float32),
#   'probabilities': array([0.67860967, 0.3213903 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22272426], dtype=float32),
#   'logits': array([-1.2498606], dtype=float32),
#   'probabilities': array([0.7772757 , 0.22272426], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09913869], dtype=float32),
#   'logits': array([-2.2068315], dtype=float32),
#   'probabilities': array([0.9008613, 0.0991387], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12974104], dtype=float32),
#   'logits': array([-1.9032503], dtype=float32),
#   'probabilities': array([0.870259  , 0.12974104], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7258113], dtype=float32),
#   'logits': array([0.97347367], dtype=float32),
#   'probabilities': array([0.27418867, 0.7258113 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17471565], dtype=float32),
#   'logits': array([-1.5525682], dtype=float32),
#   'probabilities': array([0.82528436, 0.17471565], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13143572], dtype=float32),
#   'logits': array([-1.8883237], dtype=float32),
#   'probabilities': array([0.8685643 , 0.13143572], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1493415], dtype=float32),
#   'logits': array([-1.7397752], dtype=float32),
#   'probabilities': array([0.8506585 , 0.14934148], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4768608], dtype=float32),
#   'logits': array([-0.092623], dtype=float32),
#   'probabilities': array([0.5231392 , 0.47686076], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44052076], dtype=float32),
#   'logits': array([-0.23904878], dtype=float32),
#   'probabilities': array([0.55947924, 0.4405208 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23491319], dtype=float32),
#   'logits': array([-1.1807733], dtype=float32),
#   'probabilities': array([0.7650868, 0.2349132], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43344498], dtype=float32),
#   'logits': array([-0.26780927], dtype=float32),
#   'probabilities': array([0.56655496, 0.43344498], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18325184], dtype=float32),
#   'logits': array([-1.4944694], dtype=float32),
#   'probabilities': array([0.81674814, 0.18325184], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22728407], dtype=float32),
#   'logits': array([-1.2237108], dtype=float32),
#   'probabilities': array([0.7727159 , 0.22728409], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5054186], dtype=float32),
#   'logits': array([0.02167523], dtype=float32),
#   'probabilities': array([0.4945814, 0.5054186], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47466752], dtype=float32),
#   'logits': array([-0.10141677], dtype=float32),
#   'probabilities': array([0.5253325 , 0.47466755], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13565789], dtype=float32),
#   'logits': array([-1.8518324], dtype=float32),
#   'probabilities': array([0.86434215, 0.1356579 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38439023], dtype=float32),
#   'logits': array([-0.47095507], dtype=float32),
#   'probabilities': array([0.61560977, 0.3843902 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6534125], dtype=float32),
#   'logits': array([0.6340734], dtype=float32),
#   'probabilities': array([0.34658748, 0.6534125 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5192988], dtype=float32),
#   'logits': array([0.07723343], dtype=float32),
#   'probabilities': array([0.48070124, 0.5192988 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37711886], dtype=float32),
#   'logits': array([-0.50179523], dtype=float32),
#   'probabilities': array([0.6228811 , 0.37711886], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53921884], dtype=float32),
#   'logits': array([0.15719819], dtype=float32),
#   'probabilities': array([0.46078122, 0.53921884], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21643786], dtype=float32),
#   'logits': array([-1.2865468], dtype=float32),
#   'probabilities': array([0.7835622 , 0.21643788], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1882346], dtype=float32),
#   'logits': array([-1.4615223], dtype=float32),
#   'probabilities': array([0.8117654, 0.1882346], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13275418], dtype=float32),
#   'logits': array([-1.8768234], dtype=float32),
#   'probabilities': array([0.86724585, 0.13275418], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2669424], dtype=float32),
#   'logits': array([-1.0101912], dtype=float32),
#   'probabilities': array([0.73305756, 0.2669424 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49300915], dtype=float32),
#   'logits': array([-0.02796519], dtype=float32),
#   'probabilities': array([0.50699085, 0.49300918], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65892595], dtype=float32),
#   'logits': array([0.6585115], dtype=float32),
#   'probabilities': array([0.34107405, 0.65892595], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22821246], dtype=float32),
#   'logits': array([-1.2184322], dtype=float32),
#   'probabilities': array([0.7717875 , 0.22821248], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16523014], dtype=float32),
#   'logits': array([-1.6198168], dtype=float32),
#   'probabilities': array([0.83476985, 0.16523013], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40494737], dtype=float32),
#   'logits': array([-0.38489276], dtype=float32),
#   'probabilities': array([0.5950526 , 0.40494737], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22381341], dtype=float32),
#   'logits': array([-1.2435802], dtype=float32),
#   'probabilities': array([0.7761866 , 0.22381341], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14381126], dtype=float32),
#   'logits': array([-1.7839891], dtype=float32),
#   'probabilities': array([0.8561887 , 0.14381127], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1824671], dtype=float32),
#   'logits': array([-1.4997213], dtype=float32),
#   'probabilities': array([0.8175329, 0.1824671], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13059406], dtype=float32),
#   'logits': array([-1.8957164], dtype=float32),
#   'probabilities': array([0.869406  , 0.13059406], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3909355], dtype=float32),
#   'logits': array([-0.4433816], dtype=float32),
#   'probabilities': array([0.6090645, 0.3909355], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7464389], dtype=float32),
#   'logits': array([1.0797089], dtype=float32),
#   'probabilities': array([0.2535611, 0.7464389], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7559854], dtype=float32),
#   'logits': array([1.1307939], dtype=float32),
#   'probabilities': array([0.2440146, 0.7559854], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51681244], dtype=float32),
#   'logits': array([0.06727505], dtype=float32),
#   'probabilities': array([0.4831876 , 0.51681244], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5000596], dtype=float32),
#   'logits': array([0.0002383], dtype=float32),
#   'probabilities': array([0.49994045, 0.5000596 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5625582], dtype=float32),
#   'logits': array([0.2515509], dtype=float32),
#   'probabilities': array([0.43744177, 0.5625582 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11376148], dtype=float32),
#   'logits': array([-2.0528822], dtype=float32),
#   'probabilities': array([0.8862385 , 0.11376148], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52249265], dtype=float32),
#   'logits': array([0.09003127], dtype=float32),
#   'probabilities': array([0.4775074 , 0.52249265], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7449413], dtype=float32),
#   'logits': array([1.0718116], dtype=float32),
#   'probabilities': array([0.25505874, 0.7449413 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40608367], dtype=float32),
#   'logits': array([-0.3801791], dtype=float32),
#   'probabilities': array([0.5939163, 0.4060837], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25960624], dtype=float32),
#   'logits': array([-1.0480161], dtype=float32),
#   'probabilities': array([0.74039376, 0.25960627], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32742035], dtype=float32),
#   'logits': array([-0.7198757], dtype=float32),
#   'probabilities': array([0.6725796 , 0.32742032], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5664552], dtype=float32),
#   'logits': array([0.26740277], dtype=float32),
#   'probabilities': array([0.43354484, 0.5664552 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22752845], dtype=float32),
#   'logits': array([-1.22232], dtype=float32),
#   'probabilities': array([0.7724716 , 0.22752845], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63354117], dtype=float32),
#   'logits': array([0.54743886], dtype=float32),
#   'probabilities': array([0.3664588 , 0.63354117], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41594744], dtype=float32),
#   'logits': array([-0.33943206], dtype=float32),
#   'probabilities': array([0.58405256, 0.41594744], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4124299], dtype=float32),
#   'logits': array([-0.35392928], dtype=float32),
#   'probabilities': array([0.58757013, 0.41242993], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15643777], dtype=float32),
#   'logits': array([-1.6849754], dtype=float32),
#   'probabilities': array([0.84356225, 0.15643777], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18788014], dtype=float32),
#   'logits': array([-1.4638437], dtype=float32),
#   'probabilities': array([0.8121199 , 0.18788016], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1851592], dtype=float32),
#   'logits': array([-1.4817767], dtype=float32),
#   'probabilities': array([0.81484073, 0.18515919], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42219773], dtype=float32),
#   'logits': array([-0.31375784], dtype=float32),
#   'probabilities': array([0.57780224, 0.42219776], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14775184], dtype=float32),
#   'logits': array([-1.7523437], dtype=float32),
#   'probabilities': array([0.8522482 , 0.14775185], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.71932715], dtype=float32),
#   'logits': array([0.94112647], dtype=float32),
#   'probabilities': array([0.28067285, 0.71932715], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19105612], dtype=float32),
#   'logits': array([-1.4431623], dtype=float32),
#   'probabilities': array([0.80894387, 0.19105612], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48750043], dtype=float32),
#   'logits': array([-0.05000877], dtype=float32),
#   'probabilities': array([0.5124996, 0.4875004], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15342036], dtype=float32),
#   'logits': array([-1.7080227], dtype=float32),
#   'probabilities': array([0.8465797 , 0.15342037], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65962195], dtype=float32),
#   'logits': array([0.66161025], dtype=float32),
#   'probabilities': array([0.34037796, 0.65962195], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29253617], dtype=float32),
#   'logits': array([-0.88309824], dtype=float32),
#   'probabilities': array([0.7074638 , 0.29253614], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19122365], dtype=float32),
#   'logits': array([-1.4420788], dtype=float32),
#   'probabilities': array([0.8087763 , 0.19122362], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3267279], dtype=float32),
#   'logits': array([-0.72302186], dtype=float32),
#   'probabilities': array([0.6732721, 0.3267279], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32524157], dtype=float32),
#   'logits': array([-0.7297865], dtype=float32),
#   'probabilities': array([0.67475843, 0.3252416 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1688733], dtype=float32),
#   'logits': array([-1.5936335], dtype=float32),
#   'probabilities': array([0.8311267, 0.1688733], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6851285], dtype=float32),
#   'logits': array([0.77744186], dtype=float32),
#   'probabilities': array([0.3148715, 0.6851285], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19193797], dtype=float32),
#   'logits': array([-1.4374666], dtype=float32),
#   'probabilities': array([0.808062  , 0.19193795], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17403072], dtype=float32),
#   'logits': array([-1.5573257], dtype=float32),
#   'probabilities': array([0.8259692, 0.1740307], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2675258], dtype=float32),
#   'logits': array([-1.0072122], dtype=float32),
#   'probabilities': array([0.7324742, 0.2675258], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4358235], dtype=float32),
#   'logits': array([-0.25812978], dtype=float32),
#   'probabilities': array([0.5641765, 0.4358235], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24963997], dtype=float32),
#   'logits': array([-1.1005335], dtype=float32),
#   'probabilities': array([0.75036   , 0.24963993], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12232778], dtype=float32),
#   'logits': array([-1.970569], dtype=float32),
#   'probabilities': array([0.87767226, 0.12232778], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8198304], dtype=float32),
#   'logits': array([1.5151986], dtype=float32),
#   'probabilities': array([0.18016964, 0.8198304 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64616656], dtype=float32),
#   'logits': array([0.60223114], dtype=float32),
#   'probabilities': array([0.3538334 , 0.64616656], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49791968], dtype=float32),
#   'logits': array([-0.00832129], dtype=float32),
#   'probabilities': array([0.5020803, 0.4979197], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7115262], dtype=float32),
#   'logits': array([0.90280795], dtype=float32),
#   'probabilities': array([0.2884738, 0.7115262], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12909606], dtype=float32),
#   'logits': array([-1.9089749], dtype=float32),
#   'probabilities': array([0.87090397, 0.12909608], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14045177], dtype=float32),
#   'logits': array([-1.8115427], dtype=float32),
#   'probabilities': array([0.8595482 , 0.14045177], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21432678], dtype=float32),
#   'logits': array([-1.299039], dtype=float32),
#   'probabilities': array([0.78567326, 0.21432681], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32197067], dtype=float32),
#   'logits': array([-0.74473006], dtype=float32),
#   'probabilities': array([0.6780293 , 0.32197067], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35874644], dtype=float32),
#   'logits': array([-0.5808091], dtype=float32),
#   'probabilities': array([0.6412536 , 0.35874644], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53685355], dtype=float32),
#   'logits': array([0.14768195], dtype=float32),
#   'probabilities': array([0.4631465 , 0.53685355], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55512404], dtype=float32),
#   'logits': array([0.22139621], dtype=float32),
#   'probabilities': array([0.44487593, 0.55512404], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3855945], dtype=float32),
#   'logits': array([-0.46586895], dtype=float32),
#   'probabilities': array([0.6144056, 0.3855945], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35044074], dtype=float32),
#   'logits': array([-0.6171024], dtype=float32),
#   'probabilities': array([0.64955926, 0.35044077], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33863145], dtype=float32),
#   'logits': array([-0.6693989], dtype=float32),
#   'probabilities': array([0.66136855, 0.33863142], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18486835], dtype=float32),
#   'logits': array([-1.4837056], dtype=float32),
#   'probabilities': array([0.81513166, 0.18486837], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6069551], dtype=float32),
#   'logits': array([0.43453097], dtype=float32),
#   'probabilities': array([0.39304492, 0.6069551 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13372475], dtype=float32),
#   'logits': array([-1.868419], dtype=float32),
#   'probabilities': array([0.8662752 , 0.13372475], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24001421], dtype=float32),
#   'logits': array([-1.1526016], dtype=float32),
#   'probabilities': array([0.7599858 , 0.24001421], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.537473], dtype=float32),
#   'logits': array([0.15017366], dtype=float32),
#   'probabilities': array([0.46252698, 0.537473  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33840692], dtype=float32),
#   'logits': array([-0.6704017], dtype=float32),
#   'probabilities': array([0.66159314, 0.3384069 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19154628], dtype=float32),
#   'logits': array([-1.4399941], dtype=float32),
#   'probabilities': array([0.80845374, 0.19154626], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27074206], dtype=float32),
#   'logits': array([-0.99086094], dtype=float32),
#   'probabilities': array([0.72925794, 0.27074206], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24475165], dtype=float32),
#   'logits': array([-1.1268027], dtype=float32),
#   'probabilities': array([0.75524837, 0.24475163], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13841061], dtype=float32),
#   'logits': array([-1.8285542], dtype=float32),
#   'probabilities': array([0.8615894, 0.1384106], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20494777], dtype=float32),
#   'logits': array([-1.3556527], dtype=float32),
#   'probabilities': array([0.79505223, 0.20494777], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5446857], dtype=float32),
#   'logits': array([0.17922103], dtype=float32),
#   'probabilities': array([0.45531428, 0.5446857 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67755425], dtype=float32),
#   'logits': array([0.74255455], dtype=float32),
#   'probabilities': array([0.3224458 , 0.67755425], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6219238], dtype=float32),
#   'logits': array([0.4977218], dtype=float32),
#   'probabilities': array([0.3780762, 0.6219238], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6750247], dtype=float32),
#   'logits': array([0.73099995], dtype=float32),
#   'probabilities': array([0.32497534, 0.6750247 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43173885], dtype=float32),
#   'logits': array([-0.27476013], dtype=float32),
#   'probabilities': array([0.5682611 , 0.43173882], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2978412], dtype=float32),
#   'logits': array([-0.8575992], dtype=float32),
#   'probabilities': array([0.7021588, 0.2978412], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5075604], dtype=float32),
#   'logits': array([0.03024375], dtype=float32),
#   'probabilities': array([0.49243966, 0.5075604 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18371274], dtype=float32),
#   'logits': array([-1.491393], dtype=float32),
#   'probabilities': array([0.8162873 , 0.18371275], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15724696], dtype=float32),
#   'logits': array([-1.6788564], dtype=float32),
#   'probabilities': array([0.84275305, 0.15724698], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17966111], dtype=float32),
#   'logits': array([-1.5186452], dtype=float32),
#   'probabilities': array([0.82033885, 0.1796611 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48281977], dtype=float32),
#   'logits': array([-0.068748], dtype=float32),
#   'probabilities': array([0.5171802 , 0.48281974], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05829354], dtype=float32),
#   'logits': array([-2.7822022], dtype=float32),
#   'probabilities': array([0.9417064 , 0.05829354], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26737565], dtype=float32),
#   'logits': array([-1.0079784], dtype=float32),
#   'probabilities': array([0.73262435, 0.26737568], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16908136], dtype=float32),
#   'logits': array([-1.5921519], dtype=float32),
#   'probabilities': array([0.8309186 , 0.16908136], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26060283], dtype=float32),
#   'logits': array([-1.0428376], dtype=float32),
#   'probabilities': array([0.73939717, 0.26060286], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24040689], dtype=float32),
#   'logits': array([-1.15045], dtype=float32),
#   'probabilities': array([0.75959307, 0.24040689], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27821591], dtype=float32),
#   'logits': array([-0.95332855], dtype=float32),
#   'probabilities': array([0.7217841 , 0.27821591], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7629106], dtype=float32),
#   'logits': array([1.1687037], dtype=float32),
#   'probabilities': array([0.23708937, 0.7629106 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17522353], dtype=float32),
#   'logits': array([-1.5490499], dtype=float32),
#   'probabilities': array([0.8247764 , 0.17522353], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12380335], dtype=float32),
#   'logits': array([-1.9568961], dtype=float32),
#   'probabilities': array([0.8761967 , 0.12380336], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5685008], dtype=float32),
#   'logits': array([0.2757373], dtype=float32),
#   'probabilities': array([0.43149912, 0.5685008 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46785155], dtype=float32),
#   'logits': array([-0.1287716], dtype=float32),
#   'probabilities': array([0.5321485 , 0.46785152], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8370178], dtype=float32),
#   'logits': array([1.6362039], dtype=float32),
#   'probabilities': array([0.16298227, 0.8370178 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6328124], dtype=float32),
#   'logits': array([0.54430115], dtype=float32),
#   'probabilities': array([0.3671876, 0.6328124], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12572247], dtype=float32),
#   'logits': array([-1.939321], dtype=float32),
#   'probabilities': array([0.87427753, 0.12572247], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6111409], dtype=float32),
#   'logits': array([0.45211053], dtype=float32),
#   'probabilities': array([0.38885906, 0.6111409 ], dtype=float32)}]

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpq5bn3fej
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpq5bn3fej', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f194dd932b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-391751ec2827> in <module>()
# ----> 1 dnn_model.train(input_fn=input_func, steps=1000)
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     361
#     362     saving_listeners = _check_listeners_type(saving_listeners)
# --> 363     loss = self._train_model(input_fn, hooks, saving_listeners)
#     364     logging.info('Loss for final step: %s.', loss)
#     365     return self
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     841       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#     842     else:
# --> 843       return self._train_model_default(input_fn, hooks, saving_listeners)
#     844
#     845   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#     854       worker_hooks.extend(input_hooks)
#     855       estimator_spec = self._call_model_fn(
# --> 856           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#     857       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#     858                                              hooks, global_step_tensor,
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#     829
#     830     logging.info('Calling model_fn.')
# --> 831     model_fn_results = self._model_fn(features=features, **kwargs)
#     832     logging.info('Done calling model_fn.')
#     833
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     345           dropout=dropout,
#     346           input_layer_partitioner=input_layer_partitioner,
# --> 347           config=config)
#     348
#     349     super(DNNClassifier, self).__init__(
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config)
#     181         dropout=dropout,
#     182         input_layer_partitioner=input_layer_partitioner)
# --> 183     logits = logit_fn(features=features, mode=mode)
#     184
#     185     return head.create_estimator_spec(
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#      89         partitioner=input_layer_partitioner):
#      90       net = feature_column_lib.input_layer(
# ---> 91           features=features, feature_columns=feature_columns)
#      92     for layer_id, num_hidden_units in enumerate(hidden_units):
#      93       with variable_scope.variable_scope(
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars)
#     275   """
#     276   return _internal_input_layer(features, feature_columns, weight_collections,
# --> 277                                trainable, cols_to_vars)
#     278
#     279
#
# ~/anaconda/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in _internal_input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars, scope)
#     179           'Items of feature_columns must be a _DenseColumn. '
#     180           'You can wrap a categorical column with an '
# --> 181           'embedding_column or indicator_column. Given: {}'.format(column))
#     182   weight_collections = list(weight_collections or [])
#     183   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %% [markdown]
# Problems with categorical values!

# %%
embedded_group_col = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols =[num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, embedded_group_col, age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train, y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)

# %%
dnn_model.train(input_fn=input_func, steps=1000)

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y = y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)

# %% [markdown]
# 76% means a little improvement... let's use more layers

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,20,10,10], feature_columns=feat_cols, n_classes=2)
dnn_model.train(input_fn=input_func, steps=1000)
dnn_model.evaluate(eval_input_func)

# %% [markdown]
# Sweet, 78%
